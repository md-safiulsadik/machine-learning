# %%
import pandas as pd

# %%
# reading the csv file
df_exams = pd.read_csv('StudentsPerformance.csv')
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # Adding a new column

# %% [markdown]
# ## assign()

# %% [markdown]
# When to use assign?
# - Add multiple columns in a single line of code
# - When you need to overwrite the values of an existing columns (best practice)

# %% [markdown]
# It returns a new object (a copy) with all the original columns in addition to the new ones

# %%
import numpy as np

# %%
# create random numbers for our new score columns
score1 = np.random.randint(1, 100, size=1000)
score2 = np.random.randint(1, 100, size=1000)

# %%
# create a series using the random numbers
series1 = pd.Series(score1, index=np.arange(0, 1000))
series2 = pd.Series(score2, index=np.arange(0, 1000))
# series1

# %%
# using assign() to add multiple columns
df_exams = df_exams.assign(score_1=series1, score2=series2)

# %%
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    88        group B           bachelor's degree      standard
# 1    female    82        group C                some college      standard
# 2    female    92        group B             master's degree      standard
# 3      male    59        group A          associate's degree  free/reduced
# 4      male    81        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    98        group E             master's degree      standard
# 996    male    67        group C                 high school  free/reduced
# 997  female    19        group C                 high school  free/reduced
# 998  female    10        group D                some college      standard
# 999  female    68        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  score1  \
# 0                      none          72             72             74      88
# 1                 completed          69             90             88      82
# 2                      none          90             95             93      92
# 3                      none          47             57             44      59
# 4                      none          76             78             75      81
# ..                      ...         ...            ...            ...     ...
# 995               completed          88             99             95      98
# 996                    none          62             55             55      67
# 997               completed          59             71             65      19
# 998               completed          68             78             77      10
# 999                    none          77             86             86      68
#
#      score2  score_1
# 0         8       88
# 1        63       82
# 2        91       92
# 3        55       59
# 4        92       81
# ..      ...      ...
# 995      38       98
# 996      47       67
# 997      43       19
# 998      80       10
# 999       6       68
#
# [1000 rows x 12 columns]

# %% [markdown]
# ## insert()

# %% [markdown]
# Inserts a new column at a specific position or index.

# %%
# using insert() to add a column at a specific position
df_exams.insert(1, 'test 2', series1)

# %%
df_exams
# Out:
#      gender  test 2  test race/ethnicity parental level of education  \
# 0    female      88    88        group B           bachelor's degree
# 1    female      82    82        group C                some college
# 2    female      92    92        group B             master's degree
# 3      male      59    59        group A          associate's degree
# 4      male      81    81        group C                some college
# ..      ...     ...   ...            ...                         ...
# 995  female      98    98        group E             master's degree
# 996    male      67    67        group C                 high school
# 997  female      19    19        group C                 high school
# 998  female      10    10        group D                some college
# 999  female      68    68        group D                some college
#
#             lunch test preparation course  math score  reading score  \
# 0        standard                    none          72             72
# 1        standard               completed          69             90
# 2        standard                    none          90             95
# 3    free/reduced                    none          47             57
# 4        standard                    none          76             78
# ..            ...                     ...         ...            ...
# 995      standard               completed          88             99
# 996  free/reduced                    none          62             55
# 997  free/reduced               completed          59             71
# 998      standard               completed          68             78
# 999  free/reduced                    none          77             86
#
#      writing score  score1  score2  score_1
# 0               74      88       8       88
# 1               88      82      63       82
# 2               93      92      91       92
# 3               44      59      55       59
# 4               75      81      92       81
# ..             ...     ...     ...      ...
# 995             95      98      38       98
# 996             55      67      47       67
# 997             65      19      43       19
# 998             77      10      80       10
# 999             86      68       6       68
#
# [1000 rows x 13 columns]
